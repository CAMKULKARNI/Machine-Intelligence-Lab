# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:\\codes_python\\MI Lab\\week 6\\train.csv")
X = data.iloc[:, 0:-1]
y = data.iloc[:, -1]

# %%
plt.plot(range(2700), X["x1"])

# %%
normalized = (X["x1"] - X["x1"].mean())/X["x1"].std()

# %%
plt.plot(range(2700), normalized)

# %%
X["x1"]
# Out:
# 0       1537.936390
# 1        580.007929
# 2       1174.594703
# 3       1168.779987
# 4       -590.853789
#            ...
# 2695    -904.034943
# 2696     -83.844191
# 2697    -565.812932
# 2698     372.633817
# 2699    -407.740522
# Name: x1, Length: 2700, dtype: float64

# %%
normalized
# Out:
# 0       1.823444
# 1       0.715249
# 2       1.403106
# 3       1.396379
# 4      -0.639282
#           ...
# 2695   -1.001590
# 2696   -0.052739
# 2697   -0.610313
# 2698    0.475345
# 2699   -0.427444
# Name: x1, Length: 2700, dtype: float64

# %%
normalized1 = (normalized - normalized.mean())/normalized.std()

# %%
plt.plot(range(2700), normalized1)

# %%
min_nomalized = (X["x1"] - min(X["x1"]))/(max(X["x1"]) - min(X["x1"]))

# %%
plt.plot(range(2700), min_nomalized)

# %%
x = min_nomalized*np.log(min_nomalized) + (1 - min_nomalized) * np.log(1 - min_nomalized)
# x = np.tanh(X['x1'])
plt.plot(range(2700), x)
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
